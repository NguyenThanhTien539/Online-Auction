# %%
import os
from dotenv import load_dotenv
import psycopg2
from psycopg2.extras import RealDictCursor
import pandas as pd

# Load environment variables
load_dotenv()

# Get Supabase connection string
SUPABASE_CONNECTION_STRING = os.getenv("SUPABASE_CONNECTION_STRING")

# Create connection function
def get_db_connection():
    """
    Create and return a connection to Supabase PostgreSQL database
    """
    return psycopg2.connect(SUPABASE_CONNECTION_STRING)

# Test connection
try:
    conn = get_db_connection()
    print("[OK] Connected to Supabase successfully!")
    conn.close()
except Exception as e:
    print(f"[ERROR] Connection failed: {e}")
# Out:
# [OK] Connected to Supabase successfully!

# %% [markdown]
# # JWT Token Generation for API Testing
#
# This notebook demonstrates how to generate JWT access tokens for testing API endpoints that require authentication.

# %%
import jwt
from datetime import datetime, timedelta, timezone
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

def generate_access_token(user_id, role, remember_me=False):
    """
    Generate JWT access token
    
    Args:
        user_id: User ID
        role: User role
        remember_me: If True, token expires in 3 days, otherwise 1 day
    
    Returns:
        JWT token string
    """
    payload = {
        'user_id': user_id,
        'role': role,
        'exp': datetime.now(timezone.utc) + timedelta(days=3 if remember_me else 1)
    }
    
    # Get secret from environment or use default for testing
    secret = os.getenv('JWT_SECRET', 'your-secret-key-here')
    
    token = jwt.encode(payload, secret, algorithm='HS256')
    return token

# %%
def get_all_users ():
    conn = get_db_connection()
    cursor = conn.cursor(cursor_factory=RealDictCursor)
    
    query = "SELECT * FROM users"
    cursor.execute(query)
    results = cursor.fetchall()
    
    df = pd.DataFrame(results)
    
    cursor.close()
    conn.close()
    
    return df

# %%
def get_all_products ():
    conn = get_db_connection()
    cursor = conn.cursor(cursor_factory=RealDictCursor)
    
    query = "SELECT * FROM products"
    cursor.execute(query)
    results = cursor.fetchall()
    
    df = pd.DataFrame(results)
    
    cursor.close()
    conn.close()
    
    return df

# %%
def bid_amount_array(product_id):
    """
    Generate array of valid bid amounts for a product
    
    Args:
        product_id: Product ID
    
    Returns:
        List of valid bid amounts: [start_price, start_price + 1*step, ..., start_price + 10*step]
    """
    conn = get_db_connection()
    cursor = conn.cursor(cursor_factory=RealDictCursor)
    
    # Get start_price and step_price from products table
    query = "SELECT current_price, step_price FROM products WHERE product_id = %s"
    cursor.execute(query, (product_id,))
    result = cursor.fetchone()
    
    cursor.close()
    conn.close()
    
    if not result:
        return []
    
    current_price = result['current_price']
    step_price = result['step_price']
    
    # Generate valid bid amounts: start_price + x*step_price where x = 1, 2, 3, 4
    valid_amounts = [current_price + (x * step_price) for x in range(1, 5)]

    return valid_amounts

# %%
import random

def get_random_users(product_id, count=5):
    """
    Get random users for testing bidding on a product
    
    Args:
        product_id: Product ID to check existence
        count: Number of random users to return (default: 5)
    
    Returns:
        List of user dictionaries, or None if product doesn't exist
    """
    conn = get_db_connection()
    cursor = conn.cursor(cursor_factory=RealDictCursor)
    
    # Check if product exists
    check_query = "SELECT product_id FROM products WHERE product_id = %s"
    cursor.execute(check_query, (product_id,))
    product = cursor.fetchone()
    
    if not product:
        cursor.close()
        conn.close()
        print(f"[ERROR] Product ID {product_id} does not exist!")
        return None
    
    # Get all users
    users_query = "SELECT user_id, username, email, role FROM users"
    cursor.execute(users_query)
    all_users = cursor.fetchall()
    
    cursor.close()
    conn.close()
    
    if len(all_users) < count:
        print(f"[WARNING] Only {len(all_users)} users available, returning all")
        return list(all_users)
    
    # Randomly select users
    random_users = random.sample(all_users, count)
    
    return random_users

# %%
import time
import requests

# ==============================================================================
# Bot Auction Bidding Simulation
# ==============================================================================

def run_simulation_for_product(product_id):
    """Run bidding simulation for a specific product"""
    print(f"\n{'='*60}")
    print(f"Starting Bot Auction Simulation for Product {product_id}")
    print(f"{'='*60}\n")
    
    # Get random users
    users = get_random_users(product_id, count=5)
    if not users:
        print("[ERROR] Cannot proceed - product does not exist")
        return None
    
    # Generate JWT tokens for each user
    user_tokens = {}
    for user in users:
        token = generate_access_token(user['user_id'], user['role'], remember_me=False)
        user_tokens[user['user_id']] = token

    
    # API endpoint
    api_url = "http://localhost:5000/api/bid/play"
    
    # Random number of bids (5-10)
    num_bids = random.randint(5, 10)
    
    # Simulate bidding
    successful_bids = 0
    failed_bids = 0
    
    for i in range(num_bids):
        # Random select user
        user = random.choice(users)
        user_id = user['user_id']
        username = user['username']
        
        # Get valid bid amounts for this product (refresh each time)
        valid_bids = bid_amount_array(product_id)
        if not valid_bids:
            print(f"[WARNING] No valid bids available, skipping...")
            continue
            
        max_price = random.choice(valid_bids)
        
        # Get token for this user
        token = user_tokens[user_id]
        
        # Prepare request
        cookies = {'accessToken': token}
        payload = {
            'product_id': product_id,
            'max_price': max_price
        }
        
        print(f"[{i+1}/{num_bids}] User: {username} (ID: {user_id}) - Bidding: {max_price:,.0f} VND")
        
        try:
            response = requests.post(api_url, cookies=cookies, json=payload)
            
            if response.status_code == 200:
                result = response.json()
                print(f"        [SUCCESS] {result.get('message', 'Bid placed')}")
                successful_bids += 1
            else:
                print(f"        [FAILED] Status {response.status_code} - {response.text[:100]}")
                failed_bids += 1
        except Exception as e:
            print(f"        [ERROR] {str(e)[:100]}")
            failed_bids += 1
        
        # Add delay between requests (0.5-2 seconds)
        delay = random.uniform(1.5, 3.0)
        time.sleep(delay)
    
    # Summary
    print(f"\n{'='*60}")
    print(f"Simulation Complete for Product {product_id}!")
    print(f"{'='*60}")
    print(f"Successful bids: {successful_bids}")
    print(f"Failed bids: {failed_bids}")
    print(f"Success rate: {(successful_bids/num_bids)*100:.1f}%")
    print(f"{'='*60}\n")
    
    return {
        'product_id': product_id,
        'successful': successful_bids,
        'failed': failed_bids,
        'total': num_bids
    }

# ==============================================================================
# Main Menu
# ==============================================================================

print("\n" + "="*60)
print("Bot Auction Bidding Simulation")
print("="*60)
print("Select mode:")
print("  1. Simulate for a specific product ID")
print("  2. Simulate for 10 random products")
print("="*60)

mode = input("Enter your choice (1 or 2): ").strip()

if mode == "1":
    # Single product mode
    product_id_input = input("Enter product_id: ")
    product_id = int(product_id_input)
    run_simulation_for_product(product_id)
    
elif mode == "2":
    # Multiple products mode
    print("\n[INFO] Fetching 10 random products...")
    
    conn = get_db_connection()
    cursor = conn.cursor(cursor_factory=RealDictCursor)
    
    # Get 10 random products
    query = """
        SELECT product_id, product_name, current_price, start_price, step_price 
        FROM products 
        WHERE end_time > NOW()
        ORDER BY RANDOM() 
        LIMIT 10
    """
    cursor.execute(query)
    products = cursor.fetchall()
    
    cursor.close()
    conn.close()
    
    if not products:
        print("[ERROR] No products found in database")
    else:
        print(f"[OK] Found {len(products)} products\n")
        
        # Display products
        for idx, prod in enumerate(products, 1):
            print(f"{idx}. Product {prod['product_id']}: {prod['product_name']} - Current: {prod['current_price']:,.0f} VND")
        
        # Run simulation for each product
        results = []
        for idx, prod in enumerate(products, 1):
            print(f"\n{'#'*60}")
            print(f"Processing {idx}/{len(products)}: Product {prod['product_id']}")
            print(f"{'#'*60}")
            
            result = run_simulation_for_product(prod['product_id'])
            if result:
                results.append(result)
            
            # Delay between products
            if idx < len(products):
                time.sleep(2)
        
        # Final summary
        print("\n" + "="*60)
        print("FINAL SUMMARY - ALL PRODUCTS")
        print("="*60)
        total_success = sum(r['successful'] for r in results)
        total_failed = sum(r['failed'] for r in results)
        total_bids = sum(r['total'] for r in results)
        
        print(f"Total products simulated: {len(results)}")
        print(f"Total bids placed: {total_bids}")
        print(f"Total successful: {total_success}")
        print(f"Total failed: {total_failed}")
        print(f"Overall success rate: {(total_success/total_bids)*100:.1f}%")
        print("="*60 + "\n")
        
else:
    print("[ERROR] Invalid choice. Please select 1 or 2.")
# Out:
# ============================================================
# Bot Auction Bidding Simulation
# ============================================================
# Select mode:
#   1. Simulate for a specific product ID
#   2. Simulate for 10 random products
# ============================================================
#
# [INFO] Fetching 10 random products...
# [OK] Found 10 products
#
# 1. Product 41: Chân Váy Bút Chì Dáng Dài Luperi LFCV5118 - Current: 23,760,000 VND
# 2. Product 217: (MẪU MỚI) CAMERA YOOSEE BÓNG ĐÈN 2 MẮT QS211 FHD XEM 2 KHUNG HÌNH, HÌNH ẢNH SẮC NÉT, QUAY ĐÊM CÓ MÀU - HÀNG CHÍNH HÃNG - Current: 12,450,000 VND
# 3. Product 207: Camera Xiaomi Wifi 360 Mi Home Security Độ Phân Giải Full HD 1080P Đàm Thoại 2 Chiều Cảm Biến Chuyển Động, Chế Độ Chống Trộm - Hàng chính hãng - Current: 39,640,000 VND
# 4. Product 210: Camera IP Wifi EZVIZ C6N Pro 2K (3MP) - Phiên bản nâng cấp của C6N - Hàng chính hãng - Current: 48,250,000 VND
# 5. Product 62: Giày thể thao nam đế êm nhẹ, thoáng khí đế cao su đúc, chống trơn trượt hạn chế mòn – BEE GEE - GNA2016A - Current: 33,590,000 VND
# 6. Product 180: Tai nghe Logitech H150 Âm Thanh Nổi 2 Giắc - Hàng Chính Hãng - Bảo Hành 12 Tháng - Current: 19,660,000 VND
# 7. Product 274: Tượng 12 con giáp đá ngọc onyx trang trí bàn làm việc - Cao 10cm - Current: 6,360,000 VND
# 8. Product 150: Dell Latitude 5300 2in1 Core i7-8665U/Ram 8GB/SSD 256GB/13.3"FHD cảm ứng - Hàng Chính Hãng - Current: 25,560,000 VND
# 9. Product 174: Túi chống nước chất liệu PVC cho điện thoại APE hàng chính hãng Sportslink - Current: 3,750,000 VND
# 10. Product 234: TRANH VẼ SƠN DẦU - TĨNH VẬT BÌNH HOA - Current: 17,460,000 VND
#
# ############################################################
# Processing 1/10: Product 41
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 41
# ============================================================
#
# [1/8] User: janevu (ID: 53) - Bidding: 27,300,000 VND
#         [SUCCESS] Bid placed
# [2/8] User: ahoang (ID: 59) - Bidding: 30,840,000 VND
#         [SUCCESS] Bid placed
# [3/8] User: janevu (ID: 53) - Bidding: 36,540,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [4/8] User: janevu (ID: 53) - Bidding: 31,230,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [5/8] User: janevu (ID: 53) - Bidding: 33,000,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [6/8] User: jane14 (ID: 54) - Bidding: 36,540,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [7/8] User: janevu (ID: 53) - Bidding: 36,540,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [8/8] User: jane14 (ID: 54) - Bidding: 36,540,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
#
# ============================================================
# Simulation Complete for Product 41!
# ============================================================
# Successful bids: 2
# Failed bids: 6
# Success rate: 25.0%
# ============================================================
#
#
# ############################################################
# Processing 2/10: Product 217
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 217
# ============================================================
#
# [1/5] User: johnnguyen (ID: 50) - Bidding: 15,010,000 VND
#         [SUCCESS] Bid placed
# [2/5] User: LokProHehe (ID: 20) - Bidding: 17,570,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Người dùng không đủ điều kiện để đặt giá (rating < 4)"}
# [3/5] User: johnnguyen (ID: 50) - Bidding: 13,730,000 VND
#         [SUCCESS] Bid placed
# [4/5] User: Nguyễn Thanh Tiến (ID: 19) - Bidding: 17,570,000 VND
#         [SUCCESS] Bid placed
# [5/5] User: LokProHehe (ID: 20) - Bidding: 17,570,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Người dùng không đủ điều kiện để đặt giá (rating < 4)"}
#
# ============================================================
# Simulation Complete for Product 217!
# ============================================================
# Successful bids: 3
# Failed bids: 2
# Success rate: 60.0%
# ============================================================
#
#
# ############################################################
# Processing 3/10: Product 207
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 207
# ============================================================
#
# [1/10] User: Tien Thanh (ID: 77) - Bidding: 44,120,000 VND
#         [SUCCESS] Bid placed
# [2/10] User: john65 (ID: 51) - Bidding: 43,000,000 VND
#         [SUCCESS] Bid placed
# [3/10] User: dangjane (ID: 60) - Bidding: 45,240,000 VND
#         [SUCCESS] Bid placed
# [4/10] User: john39 (ID: 48) - Bidding: 48,600,000 VND
#         [SUCCESS] Bid placed
# [5/10] User: Tien Thanh (ID: 77) - Bidding: 50,840,000 VND
#         [SUCCESS] Bid placed
# [6/10] User: Tien Thanh (ID: 77) - Bidding: 53,050,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [7/10] User: john39 (ID: 48) - Bidding: 55,290,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [8/10] User: dangjane (ID: 60) - Bidding: 51,930,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [9/10] User: dangjane (ID: 60) - Bidding: 54,170,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [10/10] User: john65 (ID: 51) - Bidding: 55,290,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
#
# ============================================================
# Simulation Complete for Product 207!
# ============================================================
# Successful bids: 5
# Failed bids: 5
# Success rate: 50.0%
# ============================================================
#
#
# ############################################################
# Processing 4/10: Product 210
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 210
# ============================================================
#
# [1/7] User: Nguyễn Thanh Tiến (ID: 17) - Bidding: 49,010,000 VND
#         [SUCCESS] Bid placed
# [2/7] User: Nguyễn Thanh Tiến (ID: 17) - Bidding: 48,820,000 VND
#         [SUCCESS] Bid placed
# [3/7] User: Siuu1412 (ID: 18) - Bidding: 48,630,000 VND
#         [SUCCESS] Bid placed
# [4/7] User: Siuu1412 (ID: 18) - Bidding: 49,200,000 VND
#         [SUCCESS] Bid placed
# [5/7] User: Lok Miracle (ID: 78) - Bidding: 49,200,000 VND
#         [SUCCESS] Bid placed
# [6/7] User: john64 (ID: 58) - Bidding: 49,580,000 VND
#         [SUCCESS] Bid placed
# [7/7] User: john64 (ID: 58) - Bidding: 49,960,000 VND
#         [SUCCESS] Bid placed
#
# ============================================================
# Simulation Complete for Product 210!
# ============================================================
# Successful bids: 7
# Failed bids: 0
# Success rate: 100.0%
# ============================================================
#
#
# ############################################################
# Processing 5/10: Product 62
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 62
# ============================================================
#
# [1/5] User: john64 (ID: 58) - Bidding: 35,970,000 VND
#         [SUCCESS] Bid placed
# [2/5] User: jane14 (ID: 54) - Bidding: 38,350,000 VND
#         [SUCCESS] Bid placed
# [3/5] User: Siuu1412 (ID: 18) - Bidding: 39,540,000 VND
#         [SUCCESS] Bid placed
# [4/5] User: Siuu1412 (ID: 18) - Bidding: 41,920,000 VND
#         [SUCCESS] Bid placed
# [5/5] User: jane14 (ID: 54) - Bidding: 41,920,000 VND
#         [SUCCESS] Bid placed
#
# ============================================================
# Simulation Complete for Product 62!
# ============================================================
# Successful bids: 5
# Failed bids: 0
# Success rate: 100.0%
# ============================================================
#
#
# ############################################################
# Processing 6/10: Product 180
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 180
# ============================================================
#
# [1/8] User: ahoang (ID: 59) - Bidding: 27,300,000 VND
#         [SUCCESS] Bid placed
# [2/8] User: john85 (ID: 56) - Bidding: 21,570,000 VND
#         [SUCCESS] Bid placed
# [3/8] User: john85 (ID: 56) - Bidding: 29,210,000 VND
#         [SUCCESS] Bid placed
# [4/8] User: janevu (ID: 53) - Bidding: 33,030,000 VND
#         [SUCCESS] Bid placed
# [5/8] User: nguyenjohn (ID: 55) - Bidding: 36,850,000 VND
#         [SUCCESS] Bid placed
# [6/8] User: ahoang (ID: 59) - Bidding: 40,370,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [7/8] User: ahoang (ID: 59) - Bidding: 36,550,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [8/8] User: janevu (ID: 53) - Bidding: 42,280,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
#
# ============================================================
# Simulation Complete for Product 180!
# ============================================================
# Successful bids: 5
# Failed bids: 3
# Success rate: 62.5%
# ============================================================
#
#
# ############################################################
# Processing 7/10: Product 274
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 274
# ============================================================
#
# [1/8] User: LokProHehe (ID: 20) - Bidding: 10,060,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Người dùng không đủ điều kiện để đặt giá (rating < 4)"}
# [2/8] User: Tien Thanh (ID: 77) - Bidding: 11,910,000 VND
#         [SUCCESS] Bid placed
# [3/8] User: Tien Thanh (ID: 77) - Bidding: 13,760,000 VND
#         [SUCCESS] Bid placed
# [4/8] User: Tien Thanh (ID: 77) - Bidding: 13,760,000 VND
#         [SUCCESS] Bid placed
# [5/8] User: Tien Thanh (ID: 77) - Bidding: 11,910,000 VND
#         [SUCCESS] Bid placed
# [6/8] User: dinh le (ID: 79) - Bidding: 11,910,000 VND
#         [SUCCESS] Bid placed
# [7/8] User: john64 (ID: 58) - Bidding: 15,610,000 VND
#         [SUCCESS] Bid placed
# [8/8] User: Tien Thanh (ID: 77) - Bidding: 19,310,000 VND
#         [SUCCESS] Bid placed
#
# ============================================================
# Simulation Complete for Product 274!
# ============================================================
# Successful bids: 7
# Failed bids: 1
# Success rate: 87.5%
# ============================================================
#
#
# ############################################################
# Processing 8/10: Product 150
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 150
# ============================================================
#
# [1/10] User: janevu (ID: 46) - Bidding: 27,180,000 VND
#         [SUCCESS] Bid placed
# [2/10] User: duongjane (ID: 44) - Bidding: 26,370,000 VND
#         [SUCCESS] Bid placed
# [3/10] User: johnnguyen (ID: 50) - Bidding: 30,420,000 VND
#         [SUCCESS] Bid placed
# [4/10] User: duongjane (ID: 44) - Bidding: 29,610,000 VND
#         [SUCCESS] Bid placed
# [5/10] User: duongjane (ID: 44) - Bidding: 31,230,000 VND
#         [SUCCESS] Bid placed
# [6/10] User: johnnguyen (ID: 50) - Bidding: 32,850,000 VND
#         [SUCCESS] Bid placed
# [7/10] User: duongjane (ID: 44) - Bidding: 32,850,000 VND
#         [SUCCESS] Bid placed
# [8/10] User: enguyen (ID: 43) - Bidding: 36,090,000 VND
#         [SUCCESS] Bid placed
# [9/10] User: enguyen (ID: 43) - Bidding: 36,900,000 VND
#         [SUCCESS] Bid placed
# [10/10] User: duongjane (ID: 44) - Bidding: 36,900,000 VND
#         [SUCCESS] Bid placed
#
# ============================================================
# Simulation Complete for Product 150!
# ============================================================
# Successful bids: 10
# Failed bids: 0
# Success rate: 100.0%
# ============================================================
#
#
# ############################################################
# Processing 9/10: Product 174
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 174
# ============================================================
#
# [1/10] User: johnnguyen (ID: 50) - Bidding: 5,510,000 VND
#         [SUCCESS] Bid placed
# [2/10] User: janemai (ID: 45) - Bidding: 4,630,000 VND
#         [SUCCESS] Bid placed
# [3/10] User: janele (ID: 41) - Bidding: 8,150,000 VND
#         [SUCCESS] Bid placed
# [4/10] User: jane14 (ID: 54) - Bidding: 9,030,000 VND
#         [SUCCESS] Bid placed
# [5/10] User: johnnguyen (ID: 50) - Bidding: 10,790,000 VND
#         [SUCCESS] Bid placed
# [6/10] User: johnnguyen (ID: 50) - Bidding: 10,030,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [7/10] User: jane14 (ID: 54) - Bidding: 10,030,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [8/10] User: janemai (ID: 45) - Bidding: 12,670,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [9/10] User: johnnguyen (ID: 50) - Bidding: 11,790,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [10/10] User: janele (ID: 41) - Bidding: 11,790,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
#
# ============================================================
# Simulation Complete for Product 174!
# ============================================================
# Successful bids: 5
# Failed bids: 5
# Success rate: 50.0%
# ============================================================
#
#
# ############################################################
# Processing 10/10: Product 234
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 234
# ============================================================
#
# [1/8] User: Lok Miracle (ID: 78) - Bidding: 18,600,000 VND
#         [SUCCESS] Bid placed
# [2/8] User: john65 (ID: 51) - Bidding: 17,840,000 VND
#         [SUCCESS] Bid placed
# [3/8] User: john80 (ID: 47) - Bidding: 19,360,000 VND
#         [SUCCESS] Bid placed
# [4/8] User: Lok Miracle (ID: 78) - Bidding: 19,360,000 VND
#         [SUCCESS] Bid placed
# [5/8] User: Lok Miracle (ID: 78) - Bidding: 20,120,000 VND
#         [SUCCESS] Bid placed
# [6/8] User: john80 (ID: 47) - Bidding: 21,260,000 VND
#         [SUCCESS] Bid placed
# [7/8] User: Lok Miracle (ID: 78) - Bidding: 22,020,000 VND
#         [SUCCESS] Bid placed
# [8/8] User: janevu (ID: 53) - Bidding: 22,780,000 VND
#         [SUCCESS] Bid placed
#
# ============================================================
# Simulation Complete for Product 234!
# ============================================================
# Successful bids: 8
# Failed bids: 0
# Success rate: 100.0%
# ============================================================
#
#
# ============================================================
# FINAL SUMMARY - ALL PRODUCTS
# ============================================================
# Total products simulated: 10
# Total bids placed: 79
# Total successful: 57
# Total failed: 22
# Overall success rate: 72.2%
# ============================================================
