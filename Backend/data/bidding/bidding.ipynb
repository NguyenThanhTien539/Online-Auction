# %%
import os
from dotenv import load_dotenv
import psycopg2
from psycopg2.extras import RealDictCursor
import pandas as pd

# Load environment variables
load_dotenv()

# Get Supabase connection string
SUPABASE_CONNECTION_STRING = os.getenv("SUPABASE_CONNECTION_STRING")

# Create connection function
def get_db_connection():
    """
    Create and return a connection to Supabase PostgreSQL database
    """
    return psycopg2.connect(SUPABASE_CONNECTION_STRING)

# Test connection
try:
    conn = get_db_connection()
    print("[OK] Connected to Supabase successfully!")
    conn.close()
except Exception as e:
    print(f"[ERROR] Connection failed: {e}")
# Out:
# [OK] Connected to Supabase successfully!

# %% [markdown]
# # JWT Token Generation for API Testing
#
# This notebook demonstrates how to generate JWT access tokens for testing API endpoints that require authentication.

# %%
import jwt
from datetime import datetime, timedelta
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

def generate_access_token(user_id, role, remember_me=False):
    """
    Generate JWT access token
    
    Args:
        user_id: User ID
        role: User role
        remember_me: If True, token expires in 3 days, otherwise 1 day
    
    Returns:
        JWT token string
    """
    payload = {
        'user_id': user_id,
        'role': role,
        'exp': datetime.utcnow() + timedelta(days=3 if remember_me else 1)
    }
    
    # Get secret from environment or use default for testing
    secret = os.getenv('JWT_SECRET', 'your-secret-key-here')
    
    token = jwt.encode(payload, secret, algorithm='HS256')
    return token

# %%
def get_all_users ():
    conn = get_db_connection()
    cursor = conn.cursor(cursor_factory=RealDictCursor)
    
    query = "SELECT * FROM users"
    cursor.execute(query)
    results = cursor.fetchall()
    
    df = pd.DataFrame(results)
    
    cursor.close()
    conn.close()
    
    return df

# %%
def get_all_products ():
    conn = get_db_connection()
    cursor = conn.cursor(cursor_factory=RealDictCursor)
    
    query = "SELECT * FROM products"
    cursor.execute(query)
    results = cursor.fetchall()
    
    df = pd.DataFrame(results)
    
    cursor.close()
    conn.close()
    
    return df

# %%
def bid_amount_array(product_id):
    """
    Generate array of valid bid amounts for a product
    
    Args:
        product_id: Product ID
    
    Returns:
        List of valid bid amounts: [start_price, start_price + 1*step, ..., start_price + 10*step]
    """
    conn = get_db_connection()
    cursor = conn.cursor(cursor_factory=RealDictCursor)
    
    # Get start_price and step_price from products table
    query = "SELECT current_price, step_price FROM products WHERE product_id = %s"
    cursor.execute(query, (product_id,))
    result = cursor.fetchone()
    
    cursor.close()
    conn.close()
    
    if not result:
        return []
    
    current_price = result['current_price']
    step_price = result['step_price']
    
    # Generate valid bid amounts: start_price + x*step_price where x = 1, 2, 3, 4
    valid_amounts = [current_price + (x * step_price) for x in range(1, 5)]

    return valid_amounts

# %%
import random

def get_random_users(product_id, count=5):
    """
    Get random users for testing bidding on a product
    
    Args:
        product_id: Product ID to check existence
        count: Number of random users to return (default: 5)
    
    Returns:
        List of user dictionaries, or None if product doesn't exist
    """
    conn = get_db_connection()
    cursor = conn.cursor(cursor_factory=RealDictCursor)
    
    # Check if product exists
    check_query = "SELECT product_id FROM products WHERE product_id = %s"
    cursor.execute(check_query, (product_id,))
    product = cursor.fetchone()
    
    if not product:
        cursor.close()
        conn.close()
        print(f"[ERROR] Product ID {product_id} does not exist!")
        return None
    
    # Get all users
    users_query = "SELECT user_id, username, email, role FROM users"
    cursor.execute(users_query)
    all_users = cursor.fetchall()
    
    cursor.close()
    conn.close()
    
    if len(all_users) < count:
        print(f"[WARNING] Only {len(all_users)} users available, returning all")
        return list(all_users)
    
    # Randomly select users
    random_users = random.sample(all_users, count)
    
    return random_users

# %%
import time
import requests

# ==============================================================================
# Bot Auction Bidding Simulation
# ==============================================================================

def run_simulation_for_product(product_id):
    """Run bidding simulation for a specific product"""
    print(f"\n{'='*60}")
    print(f"Starting Bot Auction Simulation for Product {product_id}")
    print(f"{'='*60}\n")
    
    # Get random users
    users = get_random_users(product_id, count=5)
    if not users:
        print("[ERROR] Cannot proceed - product does not exist")
        return None
    
    # Generate JWT tokens for each user
    user_tokens = {}
    for user in users:
        token = generate_access_token(user['user_id'], user['role'], remember_me=False)
        user_tokens[user['user_id']] = token

    
    # API endpoint
    api_url = "http://localhost:5000/api/bid/play"
    
    # Random number of bids (5-10)
    num_bids = random.randint(5, 10)
    
    # Simulate bidding
    successful_bids = 0
    failed_bids = 0
    
    for i in range(num_bids):
        # Random select user
        user = random.choice(users)
        user_id = user['user_id']
        username = user['username']
        
        # Get valid bid amounts for this product (refresh each time)
        valid_bids = bid_amount_array(product_id)
        if not valid_bids:
            print(f"[WARNING] No valid bids available, skipping...")
            continue
            
        max_price = random.choice(valid_bids)
        
        # Get token for this user
        token = user_tokens[user_id]
        
        # Prepare request
        cookies = {'accessToken': token}
        payload = {
            'product_id': product_id,
            'max_price': max_price
        }
        
        print(f"[{i+1}/{num_bids}] User: {username} (ID: {user_id}) - Bidding: {max_price:,.0f} VND")
        
        try:
            response = requests.post(api_url, cookies=cookies, json=payload)
            
            if response.status_code == 200:
                result = response.json()
                print(f"        [SUCCESS] {result.get('message', 'Bid placed')}")
                successful_bids += 1
            else:
                print(f"        [FAILED] Status {response.status_code} - {response.text[:100]}")
                failed_bids += 1
        except Exception as e:
            print(f"        [ERROR] {str(e)[:100]}")
            failed_bids += 1
        
        # Add delay between requests (0.5-2 seconds)
        delay = random.uniform(1.5, 3.0)
        time.sleep(delay)
    
    # Summary
    print(f"\n{'='*60}")
    print(f"Simulation Complete for Product {product_id}!")
    print(f"{'='*60}")
    print(f"Successful bids: {successful_bids}")
    print(f"Failed bids: {failed_bids}")
    print(f"Success rate: {(successful_bids/num_bids)*100:.1f}%")
    print(f"{'='*60}\n")
    
    return {
        'product_id': product_id,
        'successful': successful_bids,
        'failed': failed_bids,
        'total': num_bids
    }

# ==============================================================================
# Main Menu
# ==============================================================================

print("\n" + "="*60)
print("Bot Auction Bidding Simulation")
print("="*60)
print("Select mode:")
print("  1. Simulate for a specific product ID")
print("  2. Simulate for 10 random products")
print("="*60)

mode = input("Enter your choice (1 or 2): ").strip()

if mode == "1":
    # Single product mode
    product_id_input = input("Enter product_id: ")
    product_id = int(product_id_input)
    run_simulation_for_product(product_id)
    
elif mode == "2":
    # Multiple products mode
    print("\n[INFO] Fetching 10 random products...")
    
    conn = get_db_connection()
    cursor = conn.cursor(cursor_factory=RealDictCursor)
    
    # Get 10 random products
    query = """
        SELECT product_id, product_name, current_price, start_price, step_price 
        FROM products 
        WHERE end_time > NOW()
        ORDER BY RANDOM() 
        LIMIT 10
    """
    cursor.execute(query)
    products = cursor.fetchall()
    
    cursor.close()
    conn.close()
    
    if not products:
        print("[ERROR] No products found in database")
    else:
        print(f"[OK] Found {len(products)} products\n")
        
        # Display products
        for idx, prod in enumerate(products, 1):
            print(f"{idx}. Product {prod['product_id']}: {prod['product_name']} - Current: {prod['current_price']:,.0f} VND")
        
        # Run simulation for each product
        results = []
        for idx, prod in enumerate(products, 1):
            print(f"\n{'#'*60}")
            print(f"Processing {idx}/{len(products)}: Product {prod['product_id']}")
            print(f"{'#'*60}")
            
            result = run_simulation_for_product(prod['product_id'])
            if result:
                results.append(result)
            
            # Delay between products
            if idx < len(products):
                time.sleep(2)
        
        # Final summary
        print("\n" + "="*60)
        print("FINAL SUMMARY - ALL PRODUCTS")
        print("="*60)
        total_success = sum(r['successful'] for r in results)
        total_failed = sum(r['failed'] for r in results)
        total_bids = sum(r['total'] for r in results)
        
        print(f"Total products simulated: {len(results)}")
        print(f"Total bids placed: {total_bids}")
        print(f"Total successful: {total_success}")
        print(f"Total failed: {total_failed}")
        print(f"Overall success rate: {(total_success/total_bids)*100:.1f}%")
        print("="*60 + "\n")
        
else:
    print("[ERROR] Invalid choice. Please select 1 or 2.")
# Out:
# ============================================================
# Bot Auction Bidding Simulation
# ============================================================
# Select mode:
#   1. Simulate for a specific product ID
#   2. Simulate for 10 random products
# ============================================================
#
# [INFO] Fetching 10 random products...
# [OK] Found 10 products
#
# 1. Product 242: TRANH VẼ SƠN DẦU NGHỆ THUẬT THIẾU NỮ ÁO YẾM QUÊ XƯA - Current: 28,390,000 VND
# 2. Product 126: Điện Thoại Samsung Galaxy A07 4GB/128GB - Hàng Chính Hãng - Current: 27,900,000 VND
# 3. Product 221: Camera wifi trong nhà quay quét 3MP IMOU IPC-A32EP-L - Hàng chính hãng - Current: 1,530,000 VND
# 4. Product 227: 100gr (một ít) gói hút ẩm các loại 1/2/3 gram tiện dùng cho việc bảo quản và hút ẩm trong gia đình nhãn hiệu MAX DESI hàng chính hãng - Current: 24,160,000 VND
# 5. Product 58: Chân váy xòe Zarha sang trọng - Current: 20,480,000 VND
# 6. Product 12: Áo phao nam công sở trẻ trung NAP37 - Current: 10,200,000 VND
# 7. Product 135: Điện Thoại Oppo A3 8GB/128GB - Hàng Chính Hãng - Current: 11,290,000 VND
# 8. Product 181: Tai Nghe Bluetooth Cao Cấp EQ2 5.3 Pin 7h Âm Thanh Sống Động Bass căng - Hàng Chính Hãng - Current: 28,480,000 VND
# 9. Product 199: Giá Đỡ Tản Nhiệt Laptop/ Máy tính bảng/ Ipad để bàn chất liệu hợp kim nhôm loại cao cấp nhất (Giao màu ngẫu nhiên) - Hàng Chính Hãng  - Current: 2,480,000 VND
# 10. Product 236: Tranh vẽ sơn dầu -HOA MẪU ĐƠN ( MẪU ĐƠN PHÚ QUÝ) - Current: 40,500,000 VND
#
# ############################################################
# Processing 1/10: Product 242
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 242
# ============================================================
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_26980\1061868096.py:24: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   'exp': datetime.utcnow() + timedelta(days=3 if remember_me else 1)
# [1/5] User: nguyenjohn (ID: 55) - Bidding: 36,390,000 VND
#         [SUCCESS] Bid placed
# [2/5] User: janevu (ID: 46) - Bidding: 36,390,000 VND
#         [SUCCESS] Bid placed
# [3/5] User: janevu (ID: 46) - Bidding: 44,390,000 VND
#         [SUCCESS] Bid placed
# [4/5] User: nguyenjohn (ID: 55) - Bidding: 47,740,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [5/5] User: janevu (ID: 46) - Bidding: 51,740,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
#
# ============================================================
# Simulation Complete for Product 242!
# ============================================================
# Successful bids: 3
# Failed bids: 2
# Success rate: 60.0%
# ============================================================
#
#
# ############################################################
# Processing 2/10: Product 126
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 126
# ============================================================
#
# [1/8] User: janevu (ID: 46) - Bidding: 35,420,000 VND
#         [SUCCESS] Bid placed
# [2/8] User: janevu (ID: 46) - Bidding: 35,420,000 VND
#         [SUCCESS] Bid placed
# [3/8] User: jane35 (ID: 57) - Bidding: 35,420,000 VND
#         [SUCCESS] Bid placed
# [4/8] User: wnguyen (ID: 42) - Bidding: 39,180,000 VND
#         [SUCCESS] Bid placed
# [5/8] User: jane35 (ID: 57) - Bidding: 44,820,000 VND
#         [SUCCESS] Bid placed
# [6/8] User: john64 (ID: 58) - Bidding: 47,870,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [7/8] User: wnguyen (ID: 42) - Bidding: 51,630,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [8/8] User: jane35 (ID: 57) - Bidding: 47,870,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
#
# ============================================================
# Simulation Complete for Product 126!
# ============================================================
# Successful bids: 5
# Failed bids: 3
# Success rate: 62.5%
# ============================================================
#
#
# ############################################################
# Processing 3/10: Product 221
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 221
# ============================================================
#
# [1/9] User: john85 (ID: 56) - Bidding: 2,220,000 VND
#         [SUCCESS] Bid placed
# [2/9] User: janevu (ID: 46) - Bidding: 1,760,000 VND
#         [SUCCESS] Bid placed
# [3/9] User: duongjane (ID: 44) - Bidding: 2,450,000 VND
#         [SUCCESS] Bid placed
# [4/9] User: duongjane (ID: 44) - Bidding: 2,680,000 VND
#         [SUCCESS] Bid placed
# [5/9] User: dangjane (ID: 60) - Bidding: 3,140,000 VND
#         [SUCCESS] Bid placed
# [6/9] User: john85 (ID: 56) - Bidding: 3,830,000 VND
#         [SUCCESS] Bid placed
# [7/9] User: john39 (ID: 48) - Bidding: 3,830,000 VND
#         [SUCCESS] Bid placed
# [8/9] User: john39 (ID: 48) - Bidding: 4,520,000 VND
#         [SUCCESS] Bid placed
# [9/9] User: janevu (ID: 46) - Bidding: 4,290,000 VND
#         [SUCCESS] Bid placed
#
# ============================================================
# Simulation Complete for Product 221!
# ============================================================
# Successful bids: 9
# Failed bids: 0
# Success rate: 100.0%
# ============================================================
#
#
# ############################################################
# Processing 4/10: Product 227
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 227
# ============================================================
#
# [1/5] User: janevu (ID: 53) - Bidding: 25,950,000 VND
#         [SUCCESS] Bid placed
# [2/5] User: john85 (ID: 56) - Bidding: 31,320,000 VND
#         [SUCCESS] Bid placed
# [3/5] User: john85 (ID: 56) - Bidding: 33,110,000 VND
#         [SUCCESS] Bid placed
# [4/5] User: Nguyễn Thanh Tiến (ID: 19) - Bidding: 34,950,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [5/5] User: jane35 (ID: 57) - Bidding: 33,160,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
#
# ============================================================
# Simulation Complete for Product 227!
# ============================================================
# Successful bids: 3
# Failed bids: 2
# Success rate: 60.0%
# ============================================================
#
#
# ############################################################
# Processing 5/10: Product 58
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 58
# ============================================================
#
# [1/7] User: janevu (ID: 53) - Bidding: 23,600,000 VND
#         [SUCCESS] Bid placed
# [2/7] User: jane35 (ID: 57) - Bidding: 21,260,000 VND
#         [SUCCESS] Bid placed
# [3/7] User: janemai (ID: 45) - Bidding: 22,040,000 VND
#         [SUCCESS] Bid placed
# [4/7] User: janemai (ID: 45) - Bidding: 22,820,000 VND
#         [SUCCESS] Bid placed
# [5/7] User: janemai (ID: 45) - Bidding: 25,940,000 VND
#         [SUCCESS] Bid placed
# [6/7] User: janemai (ID: 45) - Bidding: 25,940,000 VND
#         [SUCCESS] Bid placed
# [7/7] User: dinh le (ID: 79) - Bidding: 25,940,000 VND
#         [SUCCESS] Bid placed
#
# ============================================================
# Simulation Complete for Product 58!
# ============================================================
# Successful bids: 7
# Failed bids: 0
# Success rate: 100.0%
# ============================================================
#
#
# ############################################################
# Processing 6/10: Product 12
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 12
# ============================================================
#
# [1/6] User: janevu (ID: 46) - Bidding: 11,250,000 VND
#         [SUCCESS] Bid placed
# [2/6] User: john85 (ID: 56) - Bidding: 11,250,000 VND
#         [SUCCESS] Bid placed
# [3/6] User: janevu (ID: 46) - Bidding: 13,350,000 VND
#         [SUCCESS] Bid placed
# [4/6] User: johnnguyen (ID: 50) - Bidding: 12,300,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Người bán không thể đặt giá sản phẩm của chính họ"}
# [5/6] User: john85 (ID: 56) - Bidding: 14,400,000 VND
#         [SUCCESS] Bid placed
# [6/6] User: johnnguyen (ID: 50) - Bidding: 16,500,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Người bán không thể đặt giá sản phẩm của chính họ"}
#
# ============================================================
# Simulation Complete for Product 12!
# ============================================================
# Successful bids: 4
# Failed bids: 2
# Success rate: 66.7%
# ============================================================
#
#
# ############################################################
# Processing 7/10: Product 135
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 135
# ============================================================
#
# [1/7] User: Nguyễn Thanh Tiến (ID: 19) - Bidding: 13,890,000 VND
#         [SUCCESS] Bid placed
# [2/7] User: john39 (ID: 48) - Bidding: 16,490,000 VND
#         [SUCCESS] Bid placed
# [3/7] User: john39 (ID: 48) - Bidding: 16,490,000 VND
#         [SUCCESS] Bid placed
# [4/7] User: john65 (ID: 51) - Bidding: 20,390,000 VND
#         [SUCCESS] Bid placed
# [5/7] User: Lok Miracle (ID: 78) - Bidding: 17,940,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [6/7] User: john39 (ID: 48) - Bidding: 17,940,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [7/7] User: john65 (ID: 51) - Bidding: 21,840,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
#
# ============================================================
# Simulation Complete for Product 135!
# ============================================================
# Successful bids: 4
# Failed bids: 3
# Success rate: 57.1%
# ============================================================
#
#
# ############################################################
# Processing 8/10: Product 181
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 181
# ============================================================
#
# [1/7] User: janevu (ID: 53) - Bidding: 31,760,000 VND
#         [SUCCESS] Bid placed
# [2/7] User: enguyen (ID: 43) - Bidding: 30,120,000 VND
#         [SUCCESS] Bid placed
# [3/7] User: maijohn (ID: 49) - Bidding: 32,580,000 VND
#         [SUCCESS] Bid placed
# [4/7] User: maijohn (ID: 49) - Bidding: 33,400,000 VND
#         [SUCCESS] Bid placed
# [5/7] User: ahoang (ID: 59) - Bidding: 35,040,000 VND
#         [SUCCESS] Bid placed
# [6/7] User: janevu (ID: 53) - Bidding: 36,680,000 VND
#         [SUCCESS] Bid placed
# [7/7] User: john80 (ID: 47) - Bidding: 36,680,000 VND
#         [SUCCESS] Bid placed
#
# ============================================================
# Simulation Complete for Product 181!
# ============================================================
# Successful bids: 7
# Failed bids: 0
# Success rate: 100.0%
# ============================================================
#
#
# ############################################################
# Processing 9/10: Product 199
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 199
# ============================================================
#
# [1/10] User: ahoang (ID: 59) - Bidding: 7,160,000 VND
#         [SUCCESS] Bid placed
# [2/10] User: johnnguyen (ID: 50) - Bidding: 3,650,000 VND
#         [SUCCESS] Bid placed
# [3/10] User: duongjane (ID: 44) - Bidding: 4,820,000 VND
#         [SUCCESS] Bid placed
# [4/10] User: john80 (ID: 47) - Bidding: 5,990,000 VND
#         [SUCCESS] Bid placed
# [5/10] User: johnnguyen (ID: 50) - Bidding: 10,670,000 VND
#         [SUCCESS] Bid placed
# [6/10] User: duongjane (ID: 44) - Bidding: 11,840,000 VND
#         [SUCCESS] Bid placed
# [7/10] User: john80 (ID: 47) - Bidding: 13,010,000 VND
#         [SUCCESS] Bid placed
# [8/10] User: john80 (ID: 47) - Bidding: 16,610,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [9/10] User: johnnguyen (ID: 50) - Bidding: 15,440,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
# [10/10] User: duongjane (ID: 44) - Bidding: 14,270,000 VND
#         [FAILED] Status 400 - {"status":"error","message":"Sản phẩm không trong thời gian đấu giá"}
#
# ============================================================
# Simulation Complete for Product 199!
# ============================================================
# Successful bids: 7
# Failed bids: 3
# Success rate: 70.0%
# ============================================================
#
#
# ############################################################
# Processing 10/10: Product 236
# ############################################################
#
# ============================================================
# Starting Bot Auction Simulation for Product 236
# ============================================================
#
# [1/9] User: Nguyễn Thanh Tiến (ID: 19) - Bidding: 42,460,000 VND
#         [SUCCESS] Bid placed
# [2/9] User: janevu (ID: 53) - Bidding: 40,990,000 VND
#         [SUCCESS] Bid placed
# [3/9] User: ahoang (ID: 59) - Bidding: 41,970,000 VND
#         [SUCCESS] Bid placed
# [4/9] User: ahoang (ID: 59) - Bidding: 42,950,000 VND
#         [SUCCESS] Bid placed
# [5/9] User: janevu (ID: 53) - Bidding: 43,440,000 VND
#         [SUCCESS] Bid placed
# [6/9] User: john65 (ID: 51) - Bidding: 43,930,000 VND
#         [SUCCESS] Bid placed
# [7/9] User: john39 (ID: 48) - Bidding: 44,910,000 VND
#         [SUCCESS] Bid placed
# [8/9] User: ahoang (ID: 59) - Bidding: 45,890,000 VND
#         [SUCCESS] Bid placed
# [9/9] User: john39 (ID: 48) - Bidding: 46,380,000 VND
#         [SUCCESS] Bid placed
#
# ============================================================
# Simulation Complete for Product 236!
# ============================================================
# Successful bids: 9
# Failed bids: 0
# Success rate: 100.0%
# ============================================================
#
#
# ============================================================
# FINAL SUMMARY - ALL PRODUCTS
# ============================================================
# Total products simulated: 10
# Total bids placed: 73
# Total successful: 58
# Total failed: 15
# Overall success rate: 79.5%
# ============================================================
